# %% [markdown]
# <a href="https://colab.research.google.com/github/aniruddhagalgali/bprim_ai/blob/main/20260704.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello python")
# Out:
# Hello python

# %%
total=50
total+=30
print('total=',total, "\n.")
# Out:
# total= 80
# .

# %%
price_per_item=249
quantity = 3
shipping = 40
total_price = price_per_item * quantity
print ("Total price (excluding shipping charges) = \u20B9",total_price,"/- only!",sep="")
total_price_with_shipping = total_price + shipping
print ("Total price (including shipping charges) = \u20B9",total_price_with_shipping,"/- only!",sep="")
# Out:
# Total price (excluding shipping charges) = ₹747/- only!
# Total price (including shipping charges) = ₹787/- only!

# %%
number_of_order = 42
average_bill = 571.5
top_city = "Pune"
paid_online = True
print(type(number_of_order))
print(type(average_bill))
print(type(top_city))
print(type(paid_online))
print(type(type))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'type'>

# %%
order_amount = 1200
if order_amount > 1000:
  print ("Order of ", order_amount, " is eligible for free delivery", sep="")
else:
  print ("Order of ", order_amount, " is not eligible for free delivery", sep="")

# %%
order_amounts = [12,1250,517,1499,340]
print ("Processing ",len (order_amounts), " orders", sep="")
total_sale = 0
for order_amount in order_amounts:
  total_sale = total_sale + order_amount

print ("Total sale = \u20B9",total_sale,sep="")
# Out:
# Processing 5 orders
# Total sale = ₹3618
